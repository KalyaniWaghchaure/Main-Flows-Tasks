# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://notes.ayushsharma.in/technology'

data = requests.get(url)

print(data.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" data-bs-theme="dark">
# <head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#
# 	<title>ayush sharma (づ｡◕‿‿◕｡)づ - Technology</title>
# 	<meta name="description" content="Technology" />
#
# 	<link rel="canonical" href="https://www.ayush.nz/technology">
#
# 	<!-- RSS -->
# 	<link rel="alternate" type="application/rss+xml" title="ayush sharma (づ｡◕‿‿◕｡)づ" href="https://www.ayush.nz/feed.xml">
#
# 	<!-- Favicons -->
# 	<link rel="apple-touch-icon" sizes="180x180"
# 		href="https://www.ayush.nz/static/images/meta/favicon/apple-touch-icon.png">
# 	<link rel="icon" type="image/png" sizes="32x32"
# 		href="https://www.ayush.nz/static/images/meta/favicon/favicon-32x32.png">
# 	<link rel="icon" type="image/png" sizes="16x16"
# 		href="https://www.ayush.nz/static/images/meta/favicon/favicon-16x16.png">
# 	<link rel="manifest"
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv

def scrape_webpage(url):
    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract text (paragraphs in this example)
        paragraphs = [p.text for p in soup.find_all('p')]

        # Extract links
        links = [a['href'] for a in soup.find_all('a', href=True)]

        # Extract image sources
        images = [img['src'] for img in soup.find_all('img', src=True)]

        return {
            'text': paragraphs,
            'links': links,
            'images': images
        }
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return None

def save_to_csv(data, filename):
    with open(filename, 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Type', 'Content'])

        for key, values in data.items():
            for value in values:
                writer.writerow([key, value])

# Example usage
url = 'https://notes.ayushsharma.in/technology'  # Replace with the URL you want to scrape
scraped_data = scrape_webpage(url)

if scraped_data:
    save_to_csv(scraped_data, 'scraped_data.csv')
    print("Data has been scraped and saved to 'scraped_data.csv'")
# Out:
# Data has been scraped and saved to 'scraped_data.csv'

# %%
import csv
from collections import defaultdict

def read_csv_file(filename):
    data = defaultdict(list)

    with open(filename, 'r', newline='', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        next(csv_reader)  # Skip the header row

        for row in csv_reader:
            if len(row) == 2:
                data_type, content = row
                data[data_type].append(content)

    return data

def display_csv_contents(data):
    print("Contents of the CSV file:")
    print("-------------------------")

    for data_type, contents in data.items():
        print(f"\n{data_type.capitalize()}:")
        for i, content in enumerate(contents, 1):
            print(f"  {i}. {content}")

# Example usage
filename = 'scraped_data.csv'  # Make sure this matches the filename used in the web scraper script
csv_data = read_csv_file(filename)
display_csv_contents(csv_data)
# Out:
# Contents of the CSV file:
# -------------------------
#
# Text:
#   1.
# Consuming APIs responsibly / Nov 2022
#
#             Or: Etiquette and table manners for pinging other people's servers.
#
#
#
#
#
#
#   2.
#
#   3.
# Create a series of posts with navigation in Jekyll / Feb 2022
#
#             Add Jekyll posts into a series with series navigation.
#
#
#
#
#
#
#   4.
#
#   5.
# A practical guide to light and dark mode in Bootstrap 5 and Jekyll / Jan 2022
#
#             Implementing light and dark mode on your Bootstrap 5 + Jekyll website.
#
#
#
#
#
#
#   6.
#
#   7.
# Nemo - The Ubuntu file manager you didn’t know you needed / Jan 2022
#
#             Celebrate 2022 with a shiny new file manager for Ubuntu!
#
#
#
#
#
#
#   8.
#
#   9.
# Announcing Fediverse.to! / Jan 2022
#
#             I've been working on a search engine for Fediverse instances!
#
#
#
#
#
#
#   10.
#
#   11.
# Easy pretty URL redirects with Jekyll and Netlify / Nov 2021
#
# ...

# %%
#importing pandas library as 'pd'
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-52328141-9a27-4118-bd6b-40b8f27e1071" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52328141-9a27-4118-bd6b-40b8f27e1071">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Loading the file into pandas dataframe
dataset = pd.read_csv("unclean_data.csv", encoding="latin-1")

# %%
#Concise summary of the dataframe
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   11 non-null     float64
#  3   DIRECTOR_facebook_likes    12 non-null     object
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
#All the column names of the dataframe
dataset.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
#The total number of rows in the dataframe
dataset.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
#Total elements of the dataframe
dataset.size
# Out:
# 224

# %%
#A quick look or a sample
dataset.head(10)
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
# 5                              Spider-Man 3?ÿ                     392
# 6                                   Tangled?ÿ                     324
# 7                   Avengers: Age of Ultron?ÿ                     635
# 8                   Avengers: Age of Ultron?ÿ                     635
# 9    Harry Potter and the Half-Blood Prince?ÿ                     375
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# ...

# %%
#The latest data from the dataframe
dataset.tail()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 9      153.0                     282                   10000
# 10     183.0                     NaN                    2000
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 9                    25000  301956980         321795.0
# ...

# %%
#Null values in each column
dataset.isna().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
#Null values' presence in each column per row
dataset.isnull()
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
#Dropping the rows with null values
new_dataset = dataset.dropna()
new_dataset
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
print("The dataset length before removing null values is: ", len(dataset))
print("The dataset length after removing null values is: ", len(new_dataset))
print("The number of rows removed is: ", len(dataset) - len(new_dataset))
# Out:
# The dataset length before removing null values is:  14
# The dataset length after removing null values is:  4
# The number of rows removed is:  10

# %%
#Filling the null values with "No data"
data = dataset.fillna("No data ")
data
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
new_dataset.sum()
# Out:
# movie_title                  Spectre?ÿAvengers: Age of Ultron?ÿQuantum of S...
# num_critic_for_reviews                                                    1953
# duration                                                                 546.0
# DIRECTOR_facebook_likes                                             2010395563
# actor_3_facebook_likes                                                   20554
# ACTOR_1_facebook_likes                                                   77451
# gross                                                               1250466829
# num_voted_users                                                      1591361.0
# Cast_Total_facebook_likes                                             154209.0
# facenumber_in_poster                                                       8.0
# num_user_for_reviews                                                      5186
# budget                                                               920000000
# ...

# %%
data1  = new_dataset.filter(items=['num_critic_for_reviews', 'duration'])
data1
# Out:
#     num_critic_for_reviews  duration
# 2                      602     148.0
# 8                      635     141.0
# 12                     403     106.0
# 13                     313     151.0

# %%
filtered_data = new_dataset.loc[(new_dataset['num_critic_for_reviews'] > 25) & (new_dataset['duration'] > 1.7) | (new_dataset['num_user_for_reviews'] < 1500) & (new_dataset['num_critic_for_reviews'] < 22)]
filtered_data
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
new_dataset = new_dataset.drop_duplicates()

# %%
import pandas as pd
import numpy as np

# 1. Sorting
# Sort movies by IMDb score (descending)
sorted_by_score = dataset.sort_values('imdb_score', ascending=False)

# Sort by multiple columns: year (ascending) and budget (descending)
sorted_multi = dataset.sort_values(['title_year', 'budget'], ascending=[True, False])

# 2. Filtering
# Filter movies with IMDb score above 7.0
high_rated = dataset[dataset['imdb_score'] > 7.0]

# Filter movies from the 2000s
movies_2000s = dataset[(dataset['title_year'] >= 2000) & (dataset['title_year'] < 2010)]

# Find movies with missing duration
missing_duration = dataset[dataset['duration'].isna()]

# 3. Grouping
# Group by year and calculate average IMDb score
avg_score_by_year = dataset.groupby('title_year')['imdb_score'].mean()

print("Top 5 movies by IMDb score:")
print(sorted_by_score[['movie_title', 'imdb_score']].head())

print("\nMovies from 2000s with high ratings:")
print(movies_2000s[movies_2000s['imdb_score'] > 7][['movie_title', 'title_year', 'imdb_score']])

print("\nAverage IMDb score by year:")
print(avg_score_by_year)

#print("\nBudget statistics by director popularity:")
#print(budget_by_director_popularity)
# Out:
# Top 5 movies by IMDb score:
#                  movie_title  imdb_score
# 3    The Dark Knight Rises?ÿ         8.5
# 0                   Avatar?ÿ         7.9
# 6                  Tangled?ÿ         7.8
# 7  Avengers: Age of Ultron?ÿ         7.5
# 8  Avengers: Age of Ultron?ÿ         7.5
#
# Movies from 2000s with high ratings:
#                                      movie_title  title_year  imdb_score
# 0                                       Avatar?ÿ        2009         7.9
# 1     Pirates of the Caribbean: At World's End?ÿ        2007         7.1
# 9       Harry Potter and the Half-Blood Prince?ÿ        2009         7.5
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ        2006         7.3
#
# Average IMDb score by year:
# title_year
# 2006    6.700000
# 2007    6.650000
# 2008    6.700000
# 2009    7.700000
# 2010    7.800000
# 2012    7.550000
# 2015    7.266667
# 2016    6.900000
# Name: imdb_score, dtype: float64
